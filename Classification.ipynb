# %% [markdown]
# <a href="https://colab.research.google.com/github/isj0/DeepLearning/blob/main/Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Classification
# - Type of supervised machine learning where the goal is to predict a categorical label for a given input based on learned patterns from labeled data.
# - A program learns from the given dataset or observations and then classifies new observation into a number of classess or groups.
# - Such as Yes/No, 0 or 1, Spam ot Not Spam
# ### Common Classification Algorithms
# ### Linear Models
# - Logistic Regression
# - Support Vector Machines (SVM)
# ### Non Linear models
# - Decision Trees
# - Random Forest
# - K-Nearest Neighbors (KNN)
# - Naive Bayes
# - Neural Networks
#
# ### Evaluation Metrics
# - Accuracy: Percentage of correct predictions
# - Precision & Recall: Useful for imbalanced classes
# - F1 Score: Harmonic mean of precision and recall
# - Confusion Matrix: Breakdown of true vs. predicted labels

# %% [markdown]
# # LOGISITC REGRESSION
# - Binomial- 2 possible types of dependent variables, such as 0 or 1, Pass or fail
# - Multinomial- 3 or more possible unordered types of dependent variables, such as cat, dog, sheep
# - Ordinal- 3 or more possible ordered types of dependent variables, such as low, medium, high
#
# - Logistic regression equation can be obtained from the linear regression equation.
# - Sigmoid f(x), y = 1/ (1 + e ^-x), y = dependent, x= independent, e = Euler's constant

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Logistic Regression - Binary Classification - Single Input

# %%
df = pd.read_csv('/content/drive/MyDrive/CS 7267-Machine Learning LAB/Social_Network_Ads.csv')

# %%
df.head(3)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0

# %%
df.drop(columns=['User ID', 'Gender', 'EstimatedSalary'], axis=1, inplace=True)

# %%
df.head(3)
# Out:
#    Age  Purchased
# 0   19          0
# 1   35          0
# 2   26          0

# %%
plt.figure(figsize=(4, 3))
sns.scatterplot(x="Age", y="Purchased", data=df)
plt.show()

# %%
x = df[["Age"]]
y = df["Purchased"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test, y_test) * 100
# Out:
# 91.25

# %%
lr.predict([[40]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
plt.figure(figsize=(4, 3))
sns.scatterplot(x="Age", y="Purchased", data=df)
sns.lineplot(x="Age", y=lr.predict(x), data=df, color="red")
plt.show()

# %% [markdown]
# # Logistic Regression - Binary Classification - Multiple Inputs

# %%
df = pd.read_csv("/content/balanced_placement_data.csv")

# %%
df.head(3)
# Out:
#    cgpa  score  placed
# 0  6.87     73       1
# 1  9.75     60       1
# 2  8.66     98       1

# %%
plt.figure(figsize=(4, 3))
sns.scatterplot(x="cgpa", y="score", data=df, hue="placed")
plt.legend(loc=1)
plt.show()

# %%
x = df.iloc[:, :-1]
y = df["placed"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test, y_test) * 100
# Out:
# 75.0

# %%
lr.predict([[6.87,53]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(), y.to_numpy(), clf=lr)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
lr.coef_
# Out:
# array([[0.74155783, 0.07971539]])

# %%
lr.intercept_
# Out:
# array([-10.82826451])

# %% [markdown]
# # Logistic Regression - Binary Classification - Polynomial Features

# %%
df = pd.read_csv("/content/polynomial_classification_data.csv")

# %%
df.head(3)
# Out:
#       data1     data2  output
# 0 -1.508137  0.641881       0
# 1  2.152510  1.290190       1
# 2  0.967480  1.036760       1

# %%
plt.figure(figsize=(4, 3))
sns.scatterplot(x="data2", y="data2", data=df, hue="output")
plt.show()

# %%
x = df.iloc[:, :-1]
y = df["output"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test, y_test) * 100
# Out:
# 90.0

# %%
lr.predict([[0.967480,1.036760]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(), y.to_numpy(), clf=lr)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
df1 = pd.read_csv("/content/polynomial_classification_data.csv")

# %%
x1 = df.iloc[:, :-1]
y1 = df["output"]

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf = PolynomialFeatures(degree=3)

# %%
pf.fit(x1)
# Out:
# PolynomialFeatures(degree=3)

# %%
x1 = pd.DataFrame(pf.transform(x1))

# %%
x1_train, x1_test, y1_train, y1_test = train_test_split(x1, y1, test_size=0.2, random_state=42)

# %%
lr = LogisticRegression()

# %%
lr.fit(x1_train, y1_train)
# Out:
# LogisticRegression()

# %%
lr.score(x1_test, y1_test) * 100
# Out:
# 91.66666666666666

# %% [markdown]
# # LOGISTIC REGRESSION - MULTI-CLASS

# %%
df = pd.read_csv("/content/drive/MyDrive/CS 7267-Machine Learning LAB/iris.csv")

# %%
df.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
df["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.pairplot(df, hue="species")
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.iloc[:, :-1]
y = df["species"]

# %%
x1_train, x1_test, y1_train, y1_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# #  OVR

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(multi_class="ovr")
lr.fit(x1_train, y1_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(multi_class='ovr')

# %%
lr.score(x1_test, y1_test) * 100
# Out:
# 96.66666666666667

# %% [markdown]
# # MULTINOMIAL

# %%
lr1 = LogisticRegression(multi_class="multinomial")
lr1.fit(x1_train, y1_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(multi_class='multinomial')

# %%
lr1.score(x1_test, y1_test) * 100
# Out:
# 100.0

# %%
lr2 = LogisticRegression()
lr2.fit(x1_train, y1_train)
# Out:
# LogisticRegression()

# %%
lr2.score(x1_test, y1_test) * 100
# Out:
# 100.0

# %% [markdown]
# # CONFUSION MATRIX
# * A Confusion Matrix (Error Matrix) is a powerful tool used to evaluate the performance of classification models, especially in machine learning. It shows how well your model is predicting actual outcomes by comparing predicted labels to true labels.
# - Evalautes how well your model is doing in categorizing things correctly.
#
# - TN : True Negative -> 0, 0
# - FN : False Negative -> 1, 0
# - FP : False Positive -> 0, 1
# - TP : True Positive -> 1, 1
# - Accuracy = (TN + TP) / N (total number of data)
# - Error = (FP + FN) / N
# - Precision = TP / TP + FP
# - Recall = TP / TP + FN
# - F1 Score = 2 * (Precision * Recall) / (Precision + Recall)
# - False Negative (Type 2 Error):
# - False Positive (Type 1 Error):

# %%
df = pd.read_csv("/content/drive/MyDrive/CS 7267-Machine Learning LAB/perfectly_balanced_placement_data.csv")

# %%
df.head(3)
# Out:
#    cgpa  score  placed
# 0  6.87     73       0
# 1  9.75     60       1
# 2  8.66     98       1

# %%
x = df.iloc[:, :-1]
y = df["placed"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test, y_test) * 100
# Out:
# 80.0

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score

# %%
cf = confusion_matrix(y_test, lr.predict(x_test))

# %%
sns.heatmap(cf, annot=True)
plt.show()

# %%
precision_score(y_test, lr.predict(x_test)) * 100
# Out:
# 80.0

# %%
recall_score(y_test, lr.predict(x_test)) * 100
# Out:
# 80.0

# %%
f1_score(y_test, lr.predict(x_test)) * 100
# Out:
# 80.0

# %% [markdown]
# # IMBALANCED DATASET
# - Random Under Sampling: Reduce the majority of the class so that it will have same no as of minority.
# - Random Over Sampling: Increase the size of minority

# %%
df = pd.read_csv("/content/drive/MyDrive/CS 7267-Machine Learning LAB/Social_Network_Ads.csv")

# %%
df.head(10)
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0
# 5   27            58000          0
# 6   27            84000          0
# 7   32           150000          1
# 8   25            33000          0
# 9   35            65000          0

# %%
df.drop(columns=['User ID', 'Gender'], axis=1, inplace=True)

# %%
df['Purchased'].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
x = df.iloc[:, :-1]
y = df["Purchased"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test, y_test) * 100
# Out:
# 88.75

# %%
lr.predict([[46, 28000]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
df1 = pd.read_csv("/content/drive/MyDrive/CS 7267-Machine Learning LAB/Social_Network_Ads.csv")

# %%
df1["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
ru = RandomUnderSampler()

# %%
x = df1.iloc[:, :-1]
y = df1["Purchased"]

# %%
ru_x, ru_y = ru.fit_resample(x, y)

# %%
ru_x
# Out:
#       User ID  Gender  Age  EstimatedSalary
# 237  15753874  Female   37            80000
# 269  15583137    Male   40            61000
# 201  15708196    Male   49            74000
# 284  15638646    Male   48           141000
# 380  15683758    Male   42            64000
# ..        ...     ...  ...              ...
# 393  15635893    Male   60            42000
# 395  15691863  Female   46            41000
# 396  15706071    Male   51            23000
# 397  15654296  Female   50            20000
# 399  15594041  Female   49            36000
#
# [286 rows x 4 columns]

# %%
ru_y.value_counts()
# Out:
# Purchased
# 0    143
# 1    143
# Name: count, dtype: int64

# %% [markdown]
# # NAIVE BAYES
#
# 1.   It assumes that the
#
#
# # BAYES THEOREM
# - Determine the probability of a hypothesis with prior knowledge. Depends on conditional probability
# - P(A|B):- Posterior Probability = Probability of hypothesis A on the observed even B
# - P(B|A):- Likelihood Probability = Probability of the evidence given that the p
# - P(A):- Prior Probability
# - P(B):- Marginal Probability
#
# - Bernoulli Naive Bayes

# %%
df = pd.read_csv("/content/drive/MyDrive/CS 7267-Machine Learning LAB/perfectly_balanced_placement_data.csv")

# %%
df.head(3)
# Out:
#    cgpa  score  placed
# 0  6.87     73       0
# 1  9.75     60       1
# 2  8.66     98       1

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plt.figure(figsize=(4, 3))
sns.scatterplot(x="cgpa", y="score", data=df, hue="placed")
plt.show()

# %%
x = df.iloc[:, :-1]
y = df["placed"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
sns.kdeplot(x="score",data=df)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB

# %%
gnb = GaussianNB()

# %%
gnb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
gnb.score(x_test, y_test) * 100
# Out:
# 80.0

# %%
gnb.score(x_train, y_train)* 100
# Out:
# 80.0

# %%
mnb = MultinomialNB()

# %%
mnb.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %%
mnb.score(x_test, y_test) * 100
# Out:
# 52.5

# %%
mnb.score(x_train, y_train) * 100
# Out:
# 50.625

# %%
bnb = BernoulliNB()

# %%
bnb.fit(x_train, y_train)
# Out:
# BernoulliNB()

# %%
bnb.score(x_test, y_test) * 100
# Out:
# 50.0

# %%
bnb.score(x_train, y_train) * 100
# Out:
# 50.0

# %%
plt.figure(figsize=(4, 3))
plot_decision_regions(x.to_numpy(), y.to_numpy(), clf=gnb)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
