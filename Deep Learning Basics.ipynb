# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %%
# import basic libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('Churn_Modelling.csv')
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
# Divide the dataset into independent and dependent features

X = dataset.iloc[:, 3:13]
y = dataset.iloc[:, 13]

# %%
X.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
# Feature Engineering
geography = pd.get_dummies(X['Geography'], drop_first=True)
gender = pd.get_dummies(X['Gender'], drop_first=True)

# %%
# Concat variables with dataframe
X = X.drop(['Geography', 'Gender'], axis=1)

# %%
X.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary
# 0               1        101348.88
# 1               1        112542.58
# 2               0        113931.57
# 3               0         93826.63
# 4               1         79084.10

# %%
X = pd.concat([X, geography, gender], axis=1)

# %%
# Split the dataset into training set and test set
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)

# %%
# Feature Scaling

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train.shape
# Out:
# (8000, 11)

# %%
# Create the ANN
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LeakyReLU, PReLU, ELU,ReLU
from tensorflow.keras.layers import Dropout

# %%
# Initialize ANN
classifier = Sequential()

# %%
# Adding the Input Layer
classifier.add(Dense(units=11, activation='relu'))

# %%
# Adding the first hidden layer
classifier.add(Dense(units=7, activation='relu'))

# %%
# Adding the second hidden layer
classifier.add(Dense(units=6, activation='relu'))

# %%
# Adding the output layer
classifier.add(Dense(units=1, activation='sigmoid'))

# %%
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.01)

# %%
model_history = classifier.fit(X_train, y_train, validation_split=0.33, batch_size=10, epochs=1000)
# Out:
# Epoch 1/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.7635 - loss: 0.5772 - val_accuracy: 0.8035 - val_loss: 0.4566
# Epoch 2/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8053 - loss: 0.4451 - val_accuracy: 0.8205 - val_loss: 0.4149
# Epoch 3/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8366 - loss: 0.3912 - val_accuracy: 0.8304 - val_loss: 0.3945
# Epoch 4/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8416 - loss: 0.3718 - val_accuracy: 0.8376 - val_loss: 0.3837
# Epoch 5/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8445 - loss: 0.3634 - val_accuracy: 0.8421 - val_loss: 0.3774
# Epoch 6/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8533 - loss: 0.3452 - val_accuracy: 0.8417 - val_loss: 0.3739
# Epoch 7/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8510 - loss: 0.3531 - val_accuracy: 0.8448 - val_loss: 0.3712
# Epoch 8/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8579 - loss: 0.3452 - val_accuracy: 0.8463 - val_loss: 0.3711
# Epoch 9/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8562 - loss: 0.3424 - val_accuracy: 0.8474 - val_loss: 0.3679
# Epoch 10/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8585 - loss: 0.3302 - val_accuracy: 0.8485 - val_loss: 0.3678
# Epoch 11/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8654 - loss: 0.3243 - val_accuracy: 0.8493 - val_loss: 0.3676
# Epoch 12/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8620 - loss: 0.3239 - val_accuracy: 0.8516 - val_loss: 0.3651
# Epoch 13/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8650 - loss: 0.3279 - val_accuracy: 0.8508 - val_loss: 0.3658
# Epoch 14/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8662 - loss: 0.3255 - val_accuracy: 0.8512 - val_loss: 0.3651
# Epoch 15/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8608 - loss: 0.3389 - val_accuracy: 0.8516 - val_loss: 0.3643
# Epoch 16/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8572 - loss: 0.3453 - val_accuracy: 0.8508 - val_loss: 0.3654
# Epoch 17/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8591 - loss: 0.3363 - val_accuracy: 0.8523 - val_loss: 0.3637
# Epoch 18/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8511 - loss: 0.3426 - val_accuracy: 0.8508 - val_loss: 0.3636
# Epoch 19/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8704 - loss: 0.3188 - val_accuracy: 0.8451 - val_loss: 0.3707
# Epoch 20/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8649 - loss: 0.3190 - val_accuracy: 0.8459 - val_loss: 0.3720
# Epoch 21/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8694 - loss: 0.3191 - val_accuracy: 0.8482 - val_loss: 0.3653
# Epoch 22/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8652 - loss: 0.3199 - val_accuracy: 0.8508 - val_loss: 0.3664
# Epoch 23/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8738 - loss: 0.3155 - val_accuracy: 0.8504 - val_loss: 0.3653
# Epoch 24/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8658 - loss: 0.3240 - val_accuracy: 0.8519 - val_loss: 0.3645
# Epoch 25/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8606 - loss: 0.3376 - val_accuracy: 0.8508 - val_loss: 0.3636
# Epoch 26/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8664 - loss: 0.3157 - val_accuracy: 0.8527 - val_loss: 0.3631
# Epoch 27/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8749 - loss: 0.3081 - val_accuracy: 0.8504 - val_loss: 0.3643
# Epoch 28/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8688 - loss: 0.3183 - val_accuracy: 0.8527 - val_loss: 0.3624
# Epoch 29/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8658 - loss: 0.3218 - val_accuracy: 0.8436 - val_loss: 0.3756
# Epoch 30/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8599 - loss: 0.3226 - val_accuracy: 0.8531 - val_loss: 0.3641
# Epoch 31/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8668 - loss: 0.3083 - val_accuracy: 0.8519 - val_loss: 0.3648
# Epoch 32/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8613 - loss: 0.3295 - val_accuracy: 0.8508 - val_loss: 0.3674
# Epoch 33/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8607 - loss: 0.3170 - val_accuracy: 0.8531 - val_loss: 0.3655
# Epoch 34/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8622 - loss: 0.3244 - val_accuracy: 0.8535 - val_loss: 0.3646
# Epoch 35/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8607 - loss: 0.3321 - val_accuracy: 0.8531 - val_loss: 0.3643
# Epoch 36/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8766 - loss: 0.3006 - val_accuracy: 0.8463 - val_loss: 0.3764
# Epoch 37/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8592 - loss: 0.3197 - val_accuracy: 0.8516 - val_loss: 0.3660
# Epoch 38/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8610 - loss: 0.3220 - val_accuracy: 0.8497 - val_loss: 0.3683
# Epoch 39/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8702 - loss: 0.3093 - val_accuracy: 0.8508 - val_loss: 0.3662
# Epoch 40/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8614 - loss: 0.3181 - val_accuracy: 0.8519 - val_loss: 0.3671
# Epoch 41/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8647 - loss: 0.3187 - val_accuracy: 0.8489 - val_loss: 0.3682
# Epoch 42/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8683 - loss: 0.3069 - val_accuracy: 0.8501 - val_loss: 0.3680
# Epoch 43/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8658 - loss: 0.3176 - val_accuracy: 0.8538 - val_loss: 0.3678
# Epoch 44/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8660 - loss: 0.3169 - val_accuracy: 0.8493 - val_loss: 0.3664
# Epoch 45/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8657 - loss: 0.3121 - val_accuracy: 0.8516 - val_loss: 0.3656
# Epoch 46/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8677 - loss: 0.3062 - val_accuracy: 0.8512 - val_loss: 0.3672
# Epoch 47/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8690 - loss: 0.3025 - val_accuracy: 0.8497 - val_loss: 0.3663
# Epoch 48/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8681 - loss: 0.3054 - val_accuracy: 0.8504 - val_loss: 0.3700
# Epoch 49/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8669 - loss: 0.3124 - val_accuracy: 0.8519 - val_loss: 0.3675
# Epoch 50/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8748 - loss: 0.3063 - val_accuracy: 0.8493 - val_loss: 0.3682
# Epoch 51/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8727 - loss: 0.3049 - val_accuracy: 0.8504 - val_loss: 0.3679
# Epoch 52/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8656 - loss: 0.3110 - val_accuracy: 0.8554 - val_loss: 0.3674
# Epoch 53/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8589 - loss: 0.3243 - val_accuracy: 0.8512 - val_loss: 0.3702
# Epoch 54/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8633 - loss: 0.3192 - val_accuracy: 0.8519 - val_loss: 0.3673
# Epoch 55/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8674 - loss: 0.3109 - val_accuracy: 0.8512 - val_loss: 0.3686
# Epoch 56/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8509 - loss: 0.3340 - val_accuracy: 0.8523 - val_loss: 0.3663
# Epoch 57/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8634 - loss: 0.3072 - val_accuracy: 0.8550 - val_loss: 0.3664
# Epoch 58/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8665 - loss: 0.3068 - val_accuracy: 0.8512 - val_loss: 0.3664
# Epoch 59/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8709 - loss: 0.3053 - val_accuracy: 0.8463 - val_loss: 0.3726
# Epoch 60/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8629 - loss: 0.3109 - val_accuracy: 0.8493 - val_loss: 0.3666
# Epoch 61/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8600 - loss: 0.3200 - val_accuracy: 0.8535 - val_loss: 0.3673
# Epoch 62/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8609 - loss: 0.3222 - val_accuracy: 0.8531 - val_loss: 0.3690
# Epoch 63/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8632 - loss: 0.3109 - val_accuracy: 0.8478 - val_loss: 0.3683
# Epoch 64/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8708 - loss: 0.3140 - val_accuracy: 0.8527 - val_loss: 0.3646
# Epoch 65/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8719 - loss: 0.3018 - val_accuracy: 0.8523 - val_loss: 0.3646
# Epoch 66/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8632 - loss: 0.3195 - val_accuracy: 0.8478 - val_loss: 0.3722
# Epoch 67/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8677 - loss: 0.3153 - val_accuracy: 0.8531 - val_loss: 0.3674
# Epoch 68/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8662 - loss: 0.3122 - val_accuracy: 0.8554 - val_loss: 0.3656
# Epoch 69/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8696 - loss: 0.3123 - val_accuracy: 0.8512 - val_loss: 0.3707
# Epoch 70/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8656 - loss: 0.3130 - val_accuracy: 0.8519 - val_loss: 0.3716
# Epoch 71/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8633 - loss: 0.3155 - val_accuracy: 0.8493 - val_loss: 0.3738
# Epoch 72/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8751 - loss: 0.3087 - val_accuracy: 0.8501 - val_loss: 0.3689
# Epoch 73/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8713 - loss: 0.2963 - val_accuracy: 0.8497 - val_loss: 0.3694
# Epoch 74/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8625 - loss: 0.3099 - val_accuracy: 0.8512 - val_loss: 0.3691
# Epoch 75/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8717 - loss: 0.2972 - val_accuracy: 0.8463 - val_loss: 0.3730
# Epoch 76/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8610 - loss: 0.3179 - val_accuracy: 0.8531 - val_loss: 0.3654
# Epoch 77/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8656 - loss: 0.3069 - val_accuracy: 0.8546 - val_loss: 0.3687
# Epoch 78/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8622 - loss: 0.3105 - val_accuracy: 0.8542 - val_loss: 0.3679
# Epoch 79/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8697 - loss: 0.3043 - val_accuracy: 0.8523 - val_loss: 0.3688
# Epoch 80/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8601 - loss: 0.3111 - val_accuracy: 0.8519 - val_loss: 0.3678
# Epoch 81/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8724 - loss: 0.3101 - val_accuracy: 0.8531 - val_loss: 0.3676
# Epoch 82/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8708 - loss: 0.2965 - val_accuracy: 0.8519 - val_loss: 0.3687
# Epoch 83/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8637 - loss: 0.3152 - val_accuracy: 0.8497 - val_loss: 0.3712
# Epoch 84/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8645 - loss: 0.3058 - val_accuracy: 0.8531 - val_loss: 0.3670
# Epoch 85/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8758 - loss: 0.2914 - val_accuracy: 0.8497 - val_loss: 0.3675
# Epoch 86/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8707 - loss: 0.2985 - val_accuracy: 0.8519 - val_loss: 0.3696
# Epoch 87/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8684 - loss: 0.3063 - val_accuracy: 0.8508 - val_loss: 0.3674
# Epoch 88/1000
# 437/536 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8690 - loss: 0.3062
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1544713334.py in <cell line: 0>()
# ----> 1 model_history = classifier.fit(X_train, y_train, validation_split=0.33, batch_size=10, epochs=1000)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     375                 for step, iterator in epoch_iterator:
#     376                     callbacks.on_train_batch_begin(step)
# --> 377                     logs = self.train_function(iterator)
#     378                     callbacks.on_train_batch_end(step, logs)
#     379                     if self.stop_training:
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     218                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     219             ):
# --> 220                 opt_outputs = multi_step_on_iterator(iterator)
#     221                 if not opt_outputs.has_value():
#     222                     raise StopIteration
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1687     if cancellation_context is None:
#    1688       outputs = execute.execute(
# -> 1689           name.decode("utf-8"),
#    1690           num_outputs=num_outputs,
#    1691           inputs=tensor_inputs,
#
# KeyboardInterrupt:
